# %% [markdown]
# <a href="https://colab.research.google.com/github/Crisosth/DataMining/blob/main/C%C3%B3pia_de_Atividade_1_MINERA%C3%87%C3%83O_DE_DADOS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DISCIPLINA: MINERAÇÃO DADOS
# NOMES: ________________________________________
#
#
# **ADMINISTRAÇÃO DE DADOS **
#
# O processo de análise de dados é composto por algumas etapas essenciais:  como a definição do objeto de análise; a escolha o tipo de dados que serão analisados; a mensuração dos dados; a coleta de dados; a análise e limpeza dos dados; a análise Exploratória e a interpretação dos resultados.

# %%
#Importação das Bibliotecas
import pandas as pd

# %%
#importação da base de dados
dados = pd.read_csv("drug.csv", sep=";")
dados.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
#código da limpeza de dados
dados.isnull().sum()

# %%
#código da análise exploratória pelas estatísticas descritivas
dados.describe()

# %%
drugA = dados[dados.Drug == 'drugA']
drugB = dados[dados.Drug == 'drugB']
drugC = dados[dados.Drug == 'drugC']
drugX = dados[dados.Drug == 'drugX']
drugY = dados[dados.Drug == 'DrugY']

# %%
drugA.describe()
# Out:
#              Age    Na_to_K
# count  23.000000  23.000000
# mean   35.869565  10.918783
# std     9.696786   2.037642
# min    19.000000   6.269000
# 25%    30.000000   9.569500
# 50%    36.000000  11.227000
# 75%    44.000000  12.810000
# max    50.000000  13.972000

# %%
drugB.describe()
# Out:
#              Age    Na_to_K
# count  16.000000  16.000000
# mean   62.500000  11.524375
# std     7.127412   1.869919
# min    51.000000   8.621000
# 25%    57.750000   9.921000
# 50%    60.000000  11.174500
# 75%    68.500000  13.460750
# max    74.000000  14.239000

# %%
drugC.describe()
# Out:
#             Age    Na_to_K
# count  16.00000  16.000000
# mean   42.50000  10.633750
# std    16.72523   2.045009
# min    16.00000   6.769000
# 25%    27.50000   9.978250
# 50%    47.00000  10.490500
# 75%    50.75000  11.826750
# max    72.00000  14.160000

# %%
drugX.describe()
# Out:
#              Age    Na_to_K
# count  54.000000  54.000000
# mean   44.018519  10.650556
# std    16.435685   2.198091
# min    15.000000   6.683000
# 25%    32.000000   8.997000
# 50%    45.000000  10.524000
# 75%    56.750000  12.286250
# max    74.000000  14.642000

# %%
drugY.describe()
# Out:
#              Age    Na_to_K
# count  91.000000  91.000000
# mean   43.747253  22.374780
# std    17.031731   6.060195
# min    15.000000  15.015000
# 25%    28.500000  17.218000
# 50%    42.000000  20.489000
# 75%    58.000000  25.971500
# max    74.000000  38.247000

# %%
#código da análise exploratória por gráficos
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = dados

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="BP", y="Age",
            hue="BP", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)
# Out:
# <ipython-input-41-220f16abcbff>:9: UserWarning:
# The palette list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.boxplot(x="BP", y="Age",

# %%
#Gere um gráfico que demostre o padrão das duas classes dos dados, escolha as variáveis mais relevantes

# %%
#Escreva a análise dos resultados e o que vc encontrou de padrão nos dados
